# %% [markdown]
# <a href="https://colab.research.google.com/github/AryaBagusPutraPratama/Machine-Learning-TI-3E-2024/blob/main/Jobsheet3_Arya_Bagus_Putra_Pratama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
